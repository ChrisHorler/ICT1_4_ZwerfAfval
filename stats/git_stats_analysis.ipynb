# %% [markdown]
# # Git Repository Analysis
#
# This notebook analyzes the commits and contributors in a Git repository using the output from `git_stats.py`.
#
# ## Requirements:
# - Ensure `commits.csv` and `author_summary.csv` are in the current directory.
# - These files should be generated using the `git_stats.py` script provided earlier.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import re
from wordcloud import WordCloud

sns.set(style='whitegrid')
df = pd.read_csv('commits.csv')
authors = pd.read_csv('author_summary.csv')

# %% [markdown]
# ## 1. All Commits (head)

# %%
df.head()
# Out:
#                                      hexsha           author_name  \
# 0  4b638de3ae2a201e246255b15bc2a1fc93787808           ChrisHorler
# 1  0e8fc789c0ad05021d1c5495f2a4c8e3a4deeafc  OldMartijntje_ubuntu
# 2  455b509487e9bcea5dd8494d151090b6de6f6313  OldMartijntje_ubuntu
# 3  2f837d51a2a748908d2c26fc8bc8f73a72064f93  OldMartijntje_ubuntu
# 4  5d72621c38fb9b99601a6da468034e77c12b3391  OldMartijntje_ubuntu
#
#               author_email                       date  \
# 0      csh.sammt@gmail.com  2025-05-16T13:05:11+02:00
# 1  oldmartijntje@gmail.com  2025-05-27T12:17:41+02:00
# 2  oldmartijntje@gmail.com  2025-05-27T12:18:00+02:00
# 3  oldmartijntje@gmail.com  2025-05-27T12:21:47+02:00
# 4  oldmartijntje@gmail.com  2025-05-27T12:22:01+02:00
#
#                                              message  files_changed  \
# 0                                     Initial commit              1
# 1                                      template data              2
# 2  Merge branch 'feature/json_templating' into de...              2
# 3  Add comment to clarify purpose of empty list i...              1
# 4  Merge branch 'feature/json_templating' into de...              1
#
#    insertions  deletions  total_changes  is_merge primary_branch
# 0           1          0              1     False        develop
# 1          25          0             25     False        develop
# 2          25          0             25      True        develop
# 3           1          1              2     False        develop
# 4           1          1              2      True        develop

# %% [markdown]
# ## 2. Author Stats

# %%
# Branch diversity: count unique branches per author
branch_diversity = df.groupby('author_name')['primary_branch'].nunique().reset_index(name='branch_diversity')

# Merge with author summary
author_stats = pd.merge(authors, branch_diversity, on='author_name')
author_stats.sort_values(by='total_commits', ascending=False)
# Out:
#                 author_name  total_commits  total_merges  insertions  \
# 8          oldmartijntje_TH            164            22       19550
# 2               ChrisHorler            109             2        6918
# 3    Christian Scott Horler             82            82       60112
# 5                   Martijn             81            74      155000
# 9                  whoskhoi             46             1        1566
# 4                   JurPurr             36             1        5423
# 1                Angel Zeng             28             2       44303
# 7      OldMartijntje_ubuntu             21             5        4430
# 6  OldMartijntje_Frituurpan              8             1        1298
# 0                     Angel              1             1       13122
#
#    deletions  total_changes  most_commits  most_merges  most_changes  \
# 8       9431          28981          True        False         False
# 2       2689           9607         False        False         False
# 3       6697          66809         False         True         False
# 5      14009         169009         False        False          True
# 9        731           2297         False        False         False
# 4       1722           7145         False        False         False
# 1      16837          61140         False        False         False
# 7       2810           7240         False        False         False
# 6       1146           2444         False        False         False
# 0          0          13122         False        False         False
#
#    branch_diversity
# 8                 4
# 2                 2
# 3                 2
# 5                 4
# 9                 3
# 4                 3
# 1                 5
# 7                 1
# 6                 1
# 0                 1

# %% [markdown]
# ## 3. Most Used Commit Messages

# %%
df['message'].value_counts().head(10)
# Out:
# message
# Merge branch 'develop'                                                                                    38
# Merge branch 'feature/trash_prediction_api' into develop                                                   2
# Merge remote-tracking branch 'origin/feature/frontend-analytics' into feature/waste_page_functionality     2
# Merge branch 'feature/setup_python_deployment' into develop                                                2
# CalendarFeaturesRequest                                                                                    2
# remove comments                                                                                            2
# Deleted barchart.razor                                                                                     2
# Added more old code  In program.cs and from the graph and barchart                                         2
# Added files from the old code  Added services and models from previous frontend code.                      2
# working on prediction class                                                                                2
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Most Used Words in Commits

# %%
all_words = ' '.join(df['message']).lower()
words = re.findall(r'\b\w+\b', all_words)
common_words = Counter(words).most_common(20)
pd.DataFrame(common_words, columns=['word', 'count'])
# Out:
#            word  count
# 0       develop    199
# 1         merge    196
# 2        branch    113
# 3       feature     99
# 4          from     91
# 5          into     78
# 6       request     77
# 7          pull     76
# 8   chrishorler     76
# 9            to     65
# 10        added     62
# 11          the     61
# 12      updated     44
# 13          and     36
# 14          for     33
# 15           in     31
# 16          api     27
# 17        fixed     26
# 18         file     24
# 19   deployment     22

# %% [markdown]
# ## most common branch names

# %%
branches = df['primary_branch'].dropna().astype(str)
split_words = [re.split(r'[\/\-_]', branch) for branch in branches]
flat_words = [word.lower() for sublist in split_words for word in sublist if word]
common_branch_words = Counter(flat_words).most_common(20)
pd.DataFrame(common_branch_words, columns=['word', 'count'])
# Out:
#              word  count
# 0         develop    507
# 1          origin     54
# 2           head      41
# 3        > origin     41
# 4            main     41
# 5         feature     26
# 6          blazor     10
# 7         project     10
# 8        frontend      8
# 9       analytics      8
# 10          graph      8
# 11       barchart      8
# 12  wastecalendar      7
# 13      dbcontext      4
# 14          issue      4
# 15       aproach1      2
# 16       aproach2      2
# 17          fetch      2
# 18             db      2
# 19      endpoints      2

# %%
branches = df['primary_branch'].dropna().astype(str)
common_branch_words = Counter(branches).most_common(20)
pd.DataFrame(common_branch_words, columns=['word', 'count'])
# Out:
#                                            word  count
# 0                                       develop    507
# 1                    origin/HEAD -> origin/main     41
# 2     feature/frontend-analytics-graph-barchart      8
# 3   origin/feature/blazor_project_WasteCalendar      7
# 4              feature/dbcontext_issue_aproach1      2
# 5              feature/dbcontext_issue_aproach2      2
# 6                    feature/fetch-db-endpoints      2
# 7                    origin/feature/C4_diagrams      2
# 8    origin/feature/blazor_project_first_layout      1
# 9                     origin/blazor_project_css      1
# 10                origin/blazor_project_heatmap      1
# 11          origin/feature/trash_prediction_api      1
# 12                          feature/datascience      1

# %% [markdown]
# ## 6. Personal Commit Stats

# %%
def personal_commit_stats(author):
    # Make an explicit copy so that pandas knows you’re not working on a view
    subset = df[df['author_name'] == author].copy()

    # Now it’s safe to assign new columns
    subset['word_count'] = subset['message'].str.split().str.len()
    subset['char_count'] = subset['message'].str.len()

    return {
        'most_additions': subset['insertions'].max(),
        'least_additions': subset['insertions'].min(),
        'avg_additions': subset['insertions'].mean(),
        'most_words': subset['word_count'].max(),
        'least_words': subset['word_count'].min(),
        'avg_words': subset['word_count'].mean(),
        'most_chars': subset['char_count'].max(),
        'least_chars': subset['char_count'].min(),
        'avg_chars': subset['char_count'].mean(),
    }

pd.DataFrame({a: personal_commit_stats(a)
              for a in df['author_name'].unique()}).T
# Out:
#                           most_additions  least_additions  avg_additions  \
# ChrisHorler                        852.0              0.0      63.467890
# OldMartijntje_ubuntu              1221.0              0.0     210.952381
# JurPurr                           1850.0              1.0     150.638889
# Martijn                          34843.0              0.0    1913.580247
# OldMartijntje_Frituurpan           692.0              0.0     162.250000
# Christian Scott Horler           15264.0              1.0     733.073171
# oldmartijntje_TH                  2659.0              0.0     119.207317
# whoskhoi                           209.0              0.0      34.043478
# Angel Zeng                       15195.0              0.0    1582.250000
# Angel                            13122.0          13122.0   13122.000000
#
#                           most_words  least_words  avg_words  most_chars  \
# ChrisHorler                     24.0          1.0   6.284404       162.0
# OldMartijntje_ubuntu            11.0          1.0   4.047619        90.0
# JurPurr                         33.0          1.0   7.277778       182.0
# Martijn                         12.0          2.0   7.395062       127.0
# OldMartijntje_Frituurpan        11.0          2.0   5.000000        70.0
# Christian Scott Horler          11.0          3.0   4.451220       121.0
# oldmartijntje_TH                19.0          1.0   3.603659       104.0
# whoskhoi                        27.0          2.0   6.369565       155.0
# Angel Zeng                      37.0          2.0   6.464286       217.0
# Angel                            5.0          5.0   5.000000        56.0
#
#                           least_chars  avg_chars
# ChrisHorler                      11.0  42.027523
# OldMartijntje_ubuntu              4.0  33.809524
# JurPurr                          11.0  46.250000
# Martijn                          10.0  67.012346
# OldMartijntje_Frituurpan         13.0  35.125000
# Christian Scott Horler           22.0  45.926829
# oldmartijntje_TH                  1.0  26.390244
# whoskhoi                         11.0  41.608696
# Angel Zeng                       12.0  45.500000
# Angel                            56.0  56.000000
